# %% [markdown]
# <a href="https://colab.research.google.com/github/IrfanPurwoSaputro/pcvk_praktik1/blob/main/pvc_praktik_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(' Mengubah tingkat kecerahan citra ')
print('----------------------------------')
try:
  brightness = int(input('Masukkan nilai kecerahan: '))
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

#akses for piksel
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(original[y,x,c] + brightness, 0, 255)

#cara simpel tanpa for loop
#brightness_image = cv.convertScaleAbs(original, beta=brightness)

final_frame = cv.hconcat((original, brightness_image))
cv2_imshow(final_frame)
# Out:
#  Mengubah tingkat kecerahan citra
# ----------------------------------
# Masukkan nilai kecerahan: 50
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FC5AC786950>

# %%
#praktikum 1

print(' Mengubah kontrasa dan tingkat kecerahan citra ')
print('-----------------------------')
try:
  brightness = int(input('Masukkan nilai kecerahan [-255 - 255]: '))
  contrass = np.double(input('Masukkan nilai kontras [1.0 - 3.0]: '))
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/female.tiff')
contrast_image = np.zeros(original.shape, original.dtype)

#akses for piksel
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      contrast_image[y,x,c] = contrass * np.clip(original[y,x,c], 0, 255 +  brightness)
                                          
final_frame = cv.hconcat((original, contrast_image))
cv2_imshow(final_frame)
# Out:
#  Mengubah kontrasa dan tingkat kecerahan citra
# -----------------------------
# Masukkan nilai kecerahan [-255 - 255]: 60
# Masukkan nilai kontras [1.0 - 3.0]: 1.5
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FC5AC7E0C50>

# %%
#praktikum 2

print(' Mengubah tingkat kecerahan dengan Transformasi Log ')
print('-----------------------------')
try:
  brightness = int(input('Masukkan nilai kecerahan: '))
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/female.tiff')

c = 255 / np.log(1 + brightness)
log_image = c * (np.log(original + 1))

log_image = np.array(log_image, dtype = np.uint8)

final_frame = cv.hconcat((original, log_image))
cv2_imshow(final_frame)
# Out:
#  Mengubah tingkat kecerahan dengan Transformasi Log
# -----------------------------
# Masukkan nilai kecerahan: 40
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FC5AC418650>

# %%
#praktikum 3

print(' Grayscale Average ')
print('-------------------')

original = cv.imread('/content/drive/MyDrive/mandrill.tiff')
color_img = cv.cvtColor(original, cv.COLOR_BGR2RGB)

R, G, B = color_img[:,:,0], color_img[:,:,1], color_img[:,:,2]

gray_avg = R+G+B/3

f,axarr = plt.subplots(1,2)
axarr[0].imshow(color_img)
axarr[1].imshow(gray_avg, cmap='gray')
# Out:
#  Grayscale Average
# -------------------

# %%
print(' Grayscale Lightness ')
print('---------------------')

original = cv.imread('/content/drive/MyDrive/mandrill.tiff')
color_img = cv.cvtColor(original, cv.COLOR_BGR2RGB)

R, G, B = color_img[:,:,0], color_img[:,:,1], color_img[:,:,2]

max_channel = np.maximum(np.maximum(R,G),B)
min_channel = np.minimum(np.minimum(R,G),B)

gray_img = max_channel/2 + min_channel/2

f,axarr = plt.subplots(1,2)
axarr[0].imshow(color_img)
axarr[1].imshow(gray_img, cmap='gray')
# Out:
#  Grayscale Lightness
# ---------------------

# %%
print(' Grayscale Luminance ')
print('---------------------')

original = cv.imread('/content/drive/MyDrive/mandrill.tiff')
color_img = cv.cvtColor(original, cv.COLOR_BGR2RGB)

R, G, B = color_img[:,:,0], color_img[:,:,1], color_img[:,:,2]

gray_img = (0.2126*R) + (0.7152*G) + (0.0722*B)

f,axarr = plt.subplots(1,2)
axarr[0].imshow(color_img)
axarr[1].imshow(gray_avg, cmap='gray')
# Out:
#  Grayscale Luminance
# ---------------------
